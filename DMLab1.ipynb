# %%
print "hello Data Mining"
# Out:
# hello Data Mining

# %%
1+5
# Out:
# 6

# %%
9/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-3-dee41f0530bc> in <module>()
# ----> 1 9/0
#
# ZeroDivisionError: integer division or modulo by zero

# %%
clear

# %% [markdown]
# # Practical examples on pandas

# %%
##import required packages
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# /Anaconda/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:280: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.read_csv("hubble_data.csv")
data.head()
# Out:
#    distance  recession_velocity
# 0     0.032                 170
# 1     0.034                 290
# 2     0.214                -130
# 3     0.263                 -70
# 4     0.275                -185

# %%
data.tail()
# Out:
#     distance  recession_velocity
# 19       1.7                 960
# 20       2.0                 500
# 21       2.0                 850
# 22       2.0                 800
# 23       2.0                1090

# %%
data.head(10)
# Out:
#    distance  recession_velocity
# 0     0.032                 170
# 1     0.034                 290
# 2     0.214                -130
# 3     0.263                 -70
# 4     0.275                -185
# 5     0.275                -220
# 6     0.450                 200
# 7     0.500                 290
# 8     0.500                 270
# 9     0.630                 200

# %%
data
# Out:
#     distance  recession_velocity
# 0      0.032                 170
# 1      0.034                 290
# 2      0.214                -130
# 3      0.263                 -70
# 4      0.275                -185
# 5      0.275                -220
# 6      0.450                 200
# 7      0.500                 290
# 8      0.500                 270
# 9      0.630                 200
# 10     0.800                 300
# 11     0.900                 -30
# 12     0.900                 650
# 13     0.900                 150
# 14     0.900                 500
# 15     1.000                 920
# 16     1.100                 450
# 17     1.100                 500
# 18     1.400                 500
# 19     1.700                 960
# 20     2.000                 500
# 21     2.000                 850
# 22     2.000                 800
# 23     2.000                1090

# %%
headers= ["distance","recession_velovity"]
data_no_headers= pd.read_csv("hubble_data_no_headers.csv", names= headers)
data_no_headers.head()
# Out:
#    distance  recession_velovity
# 0     0.032                 170
# 1     0.034                 290
# 2     0.214                -130
# 3     0.263                 -70
# 4     0.275                -185

# %%
data_no_headers.head(10)
# Out:
#    distance  recession_velovity
# 0     0.032                 170
# 1     0.034                 290
# 2     0.214                -130
# 3     0.263                 -70
# 4     0.275                -185
# 5     0.275                -220
# 6     0.450                 200
# 7     0.500                 290
# 8     0.500                 270
# 9     0.630                 200

# %%
data_no_headers.tail()
# Out:
#     distance  recession_velovity
# 19       1.7                 960
# 20       2.0                 500
# 21       2.0                 850
# 22       2.0                 800
# 23       2.0                1090

# %%
data_no_headers.tail(10)
# Out:
#     distance  recession_velovity
# 14       0.9                 500
# 15       1.0                 920
# 16       1.1                 450
# 17       1.1                 500
# 18       1.4                 500
# 19       1.7                 960
# 20       2.0                 500
# 21       2.0                 850
# 22       2.0                 800
# 23       2.0                1090

# %%
data["distance"].head()
# Out:
# 0    0.032
# 1    0.034
# 2    0.214
# 3    0.263
# 4    0.275
# Name: distance, dtype: float64

# %%
data["recession_velocity"].head()
# Out:
# 0    170
# 1    290
# 2   -130
# 3    -70
# 4   -185
# Name: recession_velocity, dtype: int64

# %%
data["dssistance"].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-90d894370507> in <module>()
# ----> 1 data["dssistance"].head()
#
# /Anaconda/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# /Anaconda/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2067         # get column
#    2068         if self.columns.is_unique:
# -> 2069             return self._get_item_cache(key)
#    2070
#    2071         # duplicate columns & possible reduce dimensionality
#
# /Anaconda/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1532         res = cache.get(item)
# ...

# %%
data["distance"]
# Out:
# 0     0.032
# 1     0.034
# 2     0.214
# 3     0.263
# 4     0.275
# 5     0.275
# 6     0.450
# 7     0.500
# 8     0.500
# 9     0.630
# 10    0.800
# 11    0.900
# 12    0.900
# 13    0.900
# 14    0.900
# 15    1.000
# 16    1.100
# 17    1.100
# 18    1.400
# 19    1.700
# 20    2.000
# 21    2.000
# 22    2.000
# 23    2.000
# Name: distance, dtype: float64

# %%
data.set_index("distance",inplace=True)
data.head()
# Out:
#           recession_velocity
# distance
# 0.032                    170
# 0.034                    290
# 0.214                   -130
# 0.263                    -70
# 0.275                   -185

# %%
data.set_index("distance",inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-68eeed4a8934> in <module>()
# ----> 1 data.set_index("distance",inplace=True)
#
# /Anaconda/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in set_index(self, keys, drop, append, inplace, verify_integrity)
#    2926                 names.append(None)
#    2927             else:
# -> 2928                 level = frame[col]._values
#    2929                 names.append(col)
#    2930                 if drop:
#
# /Anaconda/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# /Anaconda/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
# ...

# %%
data
# Out:
#           recession_velocity
# distance
# 0.032                    170
# 0.034                    290
# 0.214                   -130
# 0.263                    -70
# 0.275                   -185
# 0.275                   -220
# 0.450                    200
# 0.500                    290
# 0.500                    270
# 0.630                    200
# 0.800                    300
# 0.900                    -30
# 0.900                    650
# 0.900                    150
# 0.900                    500
# 1.000                    920
# 1.100                    450
# 1.100                    500
# 1.400                    500
# 1.700                    960
# 2.000                    500
# 2.000                    850
# 2.000                    800
# 2.000                   1090

# %%
data.plot()
plt.show()

# %%
data2= pd.read_csv("wage_hours.csv")
data2.head()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-25-d877ac1306b2> in <module>()
# ----> 1 data2= pd.read_csv("wage_hours.csv")
#       2 data2.head()
#
# ...

# %%
data2= pd.read_csv("wages_hours.csv")
data2.head()
# Out:
#   HRS\tRATE\tERSP\tERNO\tNEIN\tASSET\tAGE\tDEP\tRACE\tSCHOOL
# 0  2157\t2.905\t1121\t291\t380\t7250\t38.5\t2.340...
# 1  2174\t2.970\t1128\t301\t398\t7744\t39.3\t2.335...
# 2  2062\t2.350\t1214\t326\t185\t3068\t40.1\t2.851...
# 3  2111\t2.511\t1203\t49\t117\t1632\t22.4\t1.159\...
# 4  2134\t2.791\t1013\t594\t730\t12710\t57.7\t1.22...

# %%
data2= pd.read_csv("wage_hours.csv", sep="\t")
data2.head()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-27-1a6eabaa9ad8> in <module>()
# ----> 1 data2= pd.read_csv("wage_hours.csv", sep="\t")
#       2 data2.head()
#
# ...

# %%
data2= pd.read_csv("wages_hours.csv", sep="\t")
data2.head()
# Out:
#     HRS   RATE  ERSP ERNO  NEIN  ASSET   AGE    DEP  RACE  SCHOOL
# 0  2157  2.905  1121  291   380   7250  38.5  2.340  32.1    10.5
# 1  2174  2.970  1128  301   398   7744  39.3  2.335  31.2    10.5
# 2  2062  2.350  1214  326   185   3068  40.1  2.851     *     8.9
# 3  2111  2.511  1203   49   117   1632  22.4  1.159  27.5    11.5
# 4  2134  2.791  1013  594   730  12710  57.7  1.229  32.5     8.8

# %%
data2=[["AGE","RATE"]]
data2.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-eda40e81e7cd> in <module>()
#       1 data2=[["AGE","RATE"]]
# ----> 2 data2.head()
#
# AttributeError: 'list' object has no attribute 'head'

# %%
data2= data2[["AGE","RATE"]]
data2.head()
# Out:
#     AGE   RATE
# 0  38.5  2.905
# 1  39.3  2.970
# 2  40.1  2.350
# 3  22.4  2.511
# 4  57.7  2.791

# %%
data = data2 ["AGE","RATE"]
data3.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-8e2b0579e07c> in <module>()
# ----> 1 data = data2 ["AGE","RATE"]
#       2 data3.head()
#
# TypeError: list indices must be integers, not tuple

# %%
data2 = data2[["AGE","RATE"]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-c43c19a66831> in <module>()
# ----> 1 data2 = data2[["AGE","RATE"]]
#
# TypeError: list indices must be integers, not list

# %%
data2 = data2 [["AGE","RATE"]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-0df73a5f58a2> in <module>()
# ----> 1 data2 = data2 [["AGE","RATE"]]
#
# TypeError: list indices must be integers, not list

# %%
dat = data2 [["AGE","RATE"]]
dat.head()
# Out:
#     AGE   RATE
# 0  38.5  2.905
# 1  39.3  2.970
# 2  40.1  2.350
# 3  22.4  2.511
# 4  57.7  2.791

# %%
dat1= dat.sort_values(["AGE"])
dat1.head()
# Out:
#      AGE   RATE
# 3   22.4  2.511
# 27  37.2  3.015
# 31  37.4  1.901
# 33  37.5  1.899
# 32  37.5  3.009

# %%
dat1.set_index("AGE",inplace=True)
dat1.head()
# Out:
#        RATE
# AGE
# 22.4  2.511
# 37.2  3.015
# 37.4  1.901
# 37.5  1.899
# 37.5  3.009

# %%
dat1.plot()
plt.show()

# %%
dat1 = dat.sort_values(["AGE"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-59f3a785164d> in <module>()
# ----> 1 dat1 = dat.sort_values(["AGE"])
#
# /Anaconda/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    3282
#    3283             by = by[0]
# -> 3284             k = self.xs(by, axis=other_axis).values
#    3285             if k.ndim == 2:
#    3286
#
# /Anaconda/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in xs(self, key, axis, level, drop_level)
#    1910
#    1911         if axis == 1:
# -> 1912             return self[key]
#    1913
#    1914         self._consolidate_inplace()
#
# /Anaconda/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# ...

# %%
dat.head()
# Out:
#        RATE
# AGE
# 38.5  2.905
# 39.3  2.970
# 40.1  2.350
# 22.4  2.511
# 57.7  2.791

# %%
headers = ["date","visitors"]
vistor=pd.read_csv("visitors.csv", skiprows= 4, names= headers)
vistor.head()
# Out:
#          date  visitors
# 0  2015-02-09        59
# 1  2015-02-08        79
# 2  2015-02-07        73
# 3  2015-02-06        89
# 4  2015-02-05        80

# %%
headers = ["date","visitors_new"]
vistor1=pd.read_csv("visitors-new.csv", skiprows= 4, names= headers)
vistor1.head()
# Out:
#          date  visitors_new
# 0  2015-02-09            55
# 1  2015-02-08            64
# 2  2015-02-07            61
# 3  2015-02-06            79
# 4  2015-02-05            60

# %%
mergedata= pd.merge(vistor,vistor1)
mergedata.head()
# Out:
#          date  visitors  visitors_new
# 0  2015-02-09        59            55
# 1  2015-02-08        79            64
# 2  2015-02-07        73            61
# 3  2015-02-06        89            79
# 4  2015-02-05        80            60

# %%
mergedata1= mergedata.sort_values(["date"])

# %%
mergedata1.head()
# Out:
#             visitors  visitors_new
# date
# 2014-07-14         5             4
# 2014-07-15        58            55
# 2014-07-16        18            15
# 2014-07-17        14            10
# 2014-07-18        11             9

# %%
mergedata
# Out:
#            date  visitors  visitors_new
# 0    2015-02-09        59            55
# 1    2015-02-08        79            64
# 2    2015-02-07        73            61
# 3    2015-02-06        89            79
# 4    2015-02-05        80            60
# 5    2015-02-04        92            71
# 6    2015-02-03        94            83
# 7    2015-02-02        68            58
# 8    2015-02-01        82            61
# 9    2015-01-31        66            58
# 10   2015-01-30        74            64
# 11   2015-01-29        84            65
# 12   2015-01-28        98            68
# 13   2015-01-27       128            88
# 14   2015-01-26       100            83
# 15   2015-01-25        75            58
# 16   2015-01-24        87            69
# 17   2015-01-23        95            75
# 18   2015-01-22       111            80
# 19   2015-01-21       111            95
# 20   2015-01-20       120            96
# 21   2015-01-19       151           128
# ...

# %%
sortdata= mergedata1.set_index("date", inplace= True )

# %%
sortdata

# %%
mergedata1
# Out:
#             visitors  visitors_new
# date
# 2014-07-14         5             4
# 2014-07-15        58            55
# 2014-07-16        18            15
# 2014-07-17        14            10
# 2014-07-18        11             9
# 2014-07-19         9             6
# 2014-07-20        13             8
# 2014-07-21      1544          1514
# 2014-07-22      3144          3027
# 2014-07-23       295           249
# 2014-07-24        75            53
# 2014-07-25        58            41
# 2014-07-26      1071           871
# 2014-07-27       957           785
# 2014-07-28       200           164
# 2014-07-29       158           135
# 2014-07-30       512           445
# 2014-07-31       401           270
# 2014-08-01        75            58
# 2014-08-02       100            79
# 2014-08-03       247           181
# 2014-08-04       103            77
# 2014-08-05        49            26
# 2014-08-06        25            16
# 2014-08-07        25            15
# ...

# %%
mergedata1.plot()
plt.show()

# %%
data=pd.read_csv("operating-systems.csv")

# %%
data
# Out:
#               Item  Value  Value Percent  Conversions  Conversion Percent  \
# 0        Windows 7   3290           26.2          NaN                 NaN
# 1         Mac OS X   2362           18.8          NaN                 NaN
# 2          Android   1922           15.3          NaN                 NaN
# 3      Windows 8.1   1510           12.0          NaN                 NaN
# 4           iPhone   1431           11.4          NaN                 NaN
# 5            Linux    932            7.4          NaN                 NaN
# 6     Ubuntu Linux    578            4.6          NaN                 NaN
# 7        Windows 8    191            1.5          NaN                 NaN
# 8       Windows XP    168            1.3          NaN                 NaN
# 9    Windows phone     50            0.4          NaN                 NaN
# 10       Chrome OS     45            0.4          NaN                 NaN
# 11   Windows Vista     39            0.3          NaN                 NaN
# ...
